# %% [markdown]
# # Passo 1 - Importar as libs

# %%
# import aqui as libs necessárias

# %% [markdown]
# # Passo 2 - Carregar os dados

# %%
# considere o dataset iris disponível em https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', names=['0', '1', '2', '3', '4'])

data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# # Passo 3 - Análise visual de clustering

# %%
# utilize o seaborn para visualizar em modo 2d a dispersão dos pontos
# selecione as 2 features que melhor gerem a formação dos clusters

# %% [markdown]
# # Passo 3 - Validação do clustering

# %%
# realize o treinamento do k-means e spectral clustering e calcule as métricas de NMI e Silhueta
# compare a performace com e sem a seleção de características
# plote o gráfico de dispersão passando o resultado do agrupamento
